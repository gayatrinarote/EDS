# %%
f1= open("/content/sample_data/emp.csv","r")
f2= open("/sal.csv","r")
f3= open("/content/sample_data/emp_sal.csv","w")
contents1= f1.read()
contents2= f2.read()
print(contents1)
print(contents2)
nm=[]
sal=[]
lines1=contents1.split("\n")
lines2=contents2.split("\n")
for l1 in lines1:
  words1=l1.split(",")
  for l2 in lines2:
    words2=l2.split(",")
    if(words1[0]==words[0]):
      l1=l1+","+words2[1]+","+words[2]+"\n"
      f3.write(l1)
      nm.append(wordsl[1])
      sal.append(int(words2[2]))
      print(l1)

    f1.close()
    f2.close()
    f3.close()

    print(nm)
    print(sal)
# Out:
# 1,Gayatri,Buldhana,Manager,1000000
# 2,Kiran,Kalyan,Senior Manager,40000
# 3,Shravani,Paithan,Employee,500000
# 4,Vaishnavi,Nagar,Superior,20000
# 5,Kanchan,Nashik,Employee,6000
# 1,Manager,100000000
# 2,Sr Manager,300000
# 3,Manager,10000
# 4,Employee,500000
# 5,Employee,30000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-eed7fe96f715> in <cell line: 12>()
#      14   for l2 in lines2:
#      15     words2=l2.split(",")
# ---> 16     if(words1[0]==words[0]):
#      17       l1=l1+","+words2[1]+","+words[2]+"\n"
#      18       f3.write(l1)
#
# NameError: name 'words' is not defined

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
